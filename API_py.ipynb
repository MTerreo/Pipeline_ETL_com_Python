# %%
import numpy as np
import pandas as pd
np.random.seed(12345)
import matplotlib.pyplot as plt

# %% [markdown]
# Neste exemplo vou utilizar uma API publica que vai gerar um retorno no formato JSON com os "issues" e/ou propostas de melhoria do python:

# %% [markdown]
# Primeiro passo é preparar o acesso, para isso vou usar o pacote "requests"

# %%
import requests

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
resp = requests.get(url)

# %%
resp.raise_for_status()

# %%
resp
# Out:
# <Response [200]>

# %% [markdown]
# É uma boa prática sempre chamar raise_for_status depois de usar requests.get para verificar se há erros de HTTP.
#
# O método json do objeto de resposta retornará um objeto Python contendo os dados JSON analisados como um dicionário ou lista (dependendo de qual JSON é retornado):

# %%
data = resp.json()

# %% [markdown]
# Vamos ver o primeiro elemento do JSON, que neste caso será um dicionário com muitas informações:

# %%
data[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55297',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55297/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55297/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55297/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/55297',
#  'id': 1913395391,
#  'node_id': 'PR_kwDOAA0YD85bOaTP',
#  'number': 55297,
#  'title': 'ExtensionArray.interpolate() method and tests',
#  'user': {'login': 'andrewgsavage',
#   'id': 13157776,
#   'node_id': 'MDQ6VXNlcjEzMTU3Nzc2',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/13157776?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/andrewgsavage',
#   'html_url': 'https://github.com/andrewgsavage',
#   'followers_url': 'https://api.github.com/users/andrewgsavage/followers',
#   'following_url': 'https://api.github.com/users/andrewgsavage/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/andrewgsavage/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/andrewgsavage/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/andrewgsavage/subscriptions',
#   'organizations_url': 'https://api.github.com/users/andrewgsavage/orgs',
#   'repos_url': 'https://api.github.com/users/andrewgsavage/repos',
#   'events_url': 'https://api.github.com/users/andrewgsavage/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/andrewgsavage/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'labels': [],
#  'state': 'open',
#  'locked': False,
#  'assignee': None,
#  'assignees': [],
#  'milestone': None,
#  'comments': 0,
#  'created_at': '2023-09-26T12:22:54Z',
#  'updated_at': '2023-09-26T12:22:54Z',
#  'closed_at': None,
#  'author_association': 'NONE',
#  'active_lock_reason': None,
#  'draft': False,
#  'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/55297',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55297',
#   'diff_url': 'https://github.com/pandas-dev/pandas/pull/55297.diff',
#   'patch_url': 'https://github.com/pandas-dev/pandas/pull/55297.patch',
#   'merged_at': None},
#  'body': "- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nAdds a default interpolate method for numeric EAs.\r\n\r\nPartially fixes #40252 by removing fill_value from interpolate signiture. This doesn't fully close as I haven't implemented interpolate for integers - should interpolating an IntegerArray return a IntegerArray or FloatArray? \r\n\r\nIs this the right way to go about testing interpolate? I couldn't think of a simpler way to go about it.\r\n\r\nThis works for Series(EA).interpolate(), but falls over for DataFrame(EA).interpolate() as axis=1 is passed. ",
#  'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55297/reactions',
#   'total_count': 0,
#   '+1': 0,
#   '-1': 0,
#   'laugh': 0,
#   'hooray': 0,
#   'confused': 0,
#   'heart': 0,
#   'rocket': 0,
#   'eyes': 0},
#  'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55297/timeline',
#  'performed_via_github_app': None,
#  'state_reason': None}

# %% [markdown]
# Importante nota que os resultados recuperados são baseados em dados em tempo real, os dados que você vai obter ao executar esse código serão diferentes dos mostrados nest exemplo!!!

# %% [markdown]
# Podemos passar o JSON para um dataframe de forma a facilitar a leitura dos dados:

# %%
df = pd.DataFrame(data)

# %% [markdown]
# Explorando os dados obtidos:

# %%
df.head(6)
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
# 5  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
# 5  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
# 5  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
# 5  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
# 5  https://api.github.com/repos/pandas-dev/pandas...
#
#                                             html_url          id  \
# 0    https://github.com/pandas-dev/pandas/pull/55297  1913395391
# 1  https://github.com/pandas-dev/pandas/issues/55296  1913217005
# 2  https://github.com/pandas-dev/pandas/issues/55295  1913209938
# 3  https://github.com/pandas-dev/pandas/issues/55293  1913022771
# 4  https://github.com/pandas-dev/pandas/issues/55289  1912154899
# 5  https://github.com/pandas-dev/pandas/issues/55287  1911999272
#
#                node_id  number  \
# 0  PR_kwDOAA0YD85bOaTP   55297
# 1   I_kwDOAA0YD85yCV_t   55296
# 2   I_kwDOAA0YD85yCURS   55295
# 3   I_kwDOAA0YD85yBmkz   55293
# 4   I_kwDOAA0YD85x-SsT   55289
# 5   I_kwDOAA0YD85x9sso   55287
#
#                                                title  ... closed_at  \
# 0      ExtensionArray.interpolate() method and tests  ...      None
# 1  BUG: pandas.DataFrame.to_parquet() causing mem...  ...      None
# 2  BUG: compatibility between pd.Timestamp() and ...  ...      None
# 3  BUG: `date_range` `inclusive` parameter behavi...  ...      None
# 4  ENH: Improve Filter function with Filter_Colum...  ...      None
# 5  QST: get the last one value in a dataframe's c...  ...      None
#
#   author_association active_lock_reason  draft  \
# 0               NONE               None  False
# 1               NONE               None    NaN
# 2               NONE               None    NaN
# 3               NONE               None    NaN
# 4               NONE               None    NaN
# 5               NONE               None    NaN
#
#                                         pull_request  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#                                                 body  \
# 0  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 1  ### Pandas version checks\r\n\r\n- [X] I have ...
# 2  ### Pandas version checks\n\n- [X] I have chec...
# 3  ### Pandas version checks\n\n- [X] I have chec...
# 4  ### Feature Type\n\n- [X] Adding new functiona...
# 5  ### Research\n\n- [X] I have searched the [[pa...
#
#                                            reactions  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1  {'url': 'https://api.github.com/repos/pandas-d...
# 2  {'url': 'https://api.github.com/repos/pandas-d...
# 3  {'url': 'https://api.github.com/repos/pandas-d...
# 4  {'url': 'https://api.github.com/repos/pandas-d...
# 5  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                         timeline_url performed_via_github_app  \
# 0  https://api.github.com/repos/pandas-dev/pandas...                     None
# 1  https://api.github.com/repos/pandas-dev/pandas...                     None
# 2  https://api.github.com/repos/pandas-dev/pandas...                     None
# 3  https://api.github.com/repos/pandas-dev/pandas...                     None
# 4  https://api.github.com/repos/pandas-dev/pandas...                     None
# 5  https://api.github.com/repos/pandas-dev/pandas...                     None
#
#   state_reason
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# 5         None
#
# [6 rows x 30 columns]

# %%
df.tail(3)
# Out:
#                                                   url  \
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 27  https://github.com/pandas-dev/pandas/issues/55247  1909147636
# 28    https://github.com/pandas-dev/pandas/pull/55246  1909057662
# 29  https://github.com/pandas-dev/pandas/issues/55245  1908932126
#
#                 node_id  number  \
# 27   I_kwDOAA0YD85xy0f0   55247
# 28  PR_kwDOAA0YD85a_9uu   55246
# 29   I_kwDOAA0YD85xx_4e   55245
#
#                                                 title  ... closed_at  \
# 27  BUG: NumbaPendingDeprecationWarning with numba...  ...      None
# 28                        Create broken-linkcheck.yml  ...      None
# 29  PERF: hash_pandas_object performance regressio...  ...      None
#
#    author_association active_lock_reason  draft  \
# 27               NONE               None    NaN
# 28        CONTRIBUTOR               None  False
# 29               NONE               None    NaN
#
#                                          pull_request  \
# 27                                                NaN
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29                                                NaN
#
#                                                  body  \
# 27  ### Pandas version checks\r\n\r\n- [X] I have ...
# 28  Created a Github Action to run the Sphinx link...
# 29  ### Pandas version checks\n\n- [X] I have chec...
#
#                                             reactions  \
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app state_reason
# 27                     None         None
# 28                     None         None
# 29                     None         None
#
# [3 rows x 30 columns]

# %%
df.shape
# Out:
# (30, 30)

# %%
df.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app', 'state_reason'],
#       dtype='object')

# %% [markdown]
# Vamos supor que para a análise vamos precisar somente de algumas colunas, podemos criar um daframe somente com elas:

# %%
issues = pd.DataFrame(data, columns=["id", "number", "title", "labels", "state", 'created_at'])

# %%
issues.head()
# Out:
#            id  number                                              title  \
# 0  1913395391   55297      ExtensionArray.interpolate() method and tests
# 1  1913217005   55296  BUG: pandas.DataFrame.to_parquet() causing mem...
# 2  1913209938   55295  BUG: compatibility between pd.Timestamp() and ...
# 3  1913022771   55293  BUG: `date_range` `inclusive` parameter behavi...
# 4  1912154899   55289  ENH: Improve Filter function with Filter_Colum...
#
#                                               labels state  \
# 0                                                 []  open
# 1  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 2  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 3  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 4  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
#
#              created_at
# 0  2023-09-26T12:22:54Z
# 1  2023-09-26T10:38:12Z
# 2  2023-09-26T10:33:35Z
# 3  2023-09-26T08:52:47Z
# 4  2023-09-25T19:31:26Z

# %% [markdown]
# E para exportar este dataframe para um arquivo .csv :

# %%
issues.to_csv("/content/issues.csv", encoding = 'utf-8')
